# %%
import pandas as pd
df_datos = pd.read_csv("SerieA2023.csv",sep=';')
df_datos
# Out:
#          Mes  IdServicio   Ano  IdEstablecimiento CodigoPrestacion  IdRegion  \
# 0          9          28  2023             128109         26291050         8
# 1          9          28  2023             128109         26274600         8
# 2          9          28  2023             128109         26273103         8
# 3          9          28  2023             128109         26273105         8
# 4          9          28  2023             128109         26280010         8
# ...      ...         ...   ...                ...              ...       ...
# 6099578    5          22  2023             122464         29101626        14
# 6099579    5          22  2023             122464         28010200        14
# 6099580    5          22  2023             122464         28020660        14
# 6099581    6          22  2023             122302         28011500        14
# 6099582    6          22  2023             122302         28011700        14
#
#          IdComuna  Col01   Col02  Col03  ...  Col41  Col42  Col43  Col44  \
# 0            8205    4.0     4.0    NaN  ...    NaN    NaN    NaN    NaN
# 1            8205    3.0     3.0    NaN  ...    NaN    NaN    NaN    NaN
# 2            8205   16.0    13.0    3.0  ...    NaN    NaN    NaN    NaN
# 3            8205   10.0    10.0    NaN  ...    NaN    NaN    NaN    NaN
# 4            8205    1.0     1.0    NaN  ...    NaN    NaN    NaN    NaN
# ...           ...    ...     ...    ...  ...    ...    ...    ...    ...
# 6099578     14108    1.0     0.0    1.0  ...    NaN    NaN    NaN    NaN
# 6099579     14108    1.0     NaN    NaN  ...    NaN    NaN    NaN    NaN
# 6099580     14108    2.0     NaN    NaN  ...    NaN    NaN    NaN    NaN
# 6099581     14101    NaN   303.0    NaN  ...    NaN    NaN    NaN    NaN
# 6099582     14101    NaN  1291.0    NaN  ...    NaN    NaN    NaN    NaN
#
#          Col45  Col46  Col47  Col48  Col49  Col50
# 0          NaN    NaN    NaN    NaN    NaN    NaN
# 1          NaN    NaN    NaN    NaN    NaN    NaN
# 2          NaN    NaN    NaN    NaN    NaN    NaN
# 3          NaN    NaN    NaN    NaN    NaN    NaN
# 4          NaN    NaN    NaN    NaN    NaN    NaN
# ...        ...    ...    ...    ...    ...    ...
# 6099578    NaN    NaN    NaN    NaN    NaN    NaN
# 6099579    NaN    NaN    NaN    NaN    NaN    NaN
# 6099580    NaN    NaN    NaN    NaN    NaN    NaN
# 6099581    NaN    NaN    NaN    NaN    NaN    NaN
# 6099582    NaN    NaN    NaN    NaN    NaN    NaN
#
# [6099583 rows x 57 columns]

# %%
import pandas as pd
import numpy as np
# Leer el archivo Excel
df_diccionario = pd.read_excel("A01.xlsx", skiprows=5)

# Rellenar valores faltantes hacia adelante
df_diccionario = df_diccionario.ffill(axis=0)
df_diccionario = df_diccionario.ffill(axis=1)

# Eliminar filas con menos de 3 valores no nulos
df_diccionario.dropna(axis=0, thresh=3, inplace=True)

# Limitar el DataFrame a las primeras 25 filas
df_corte = df_diccionario.iloc[:25]

# Establecer la primera fila como los nombres de las columnas y eliminar esa fila del DataFrame
df_corte.columns = df_corte.iloc[0]
df_corte = df_corte[1:]

# Renombrar las primeras columnas
listacol = df_corte.columns.tolist()
listacol[0] = 'CODIGO PRESTACION'
listacol[1] = 'TIPO CONTROL'
listacol[2] = 'PROFESIONAL'
df_corte.columns = listacol

df_corte = df_corte.iloc[:, :30]
df_corte.iloc[0, 1] = np.nan
df_corte.iloc[0, 2] = np.nan
df_corte.iloc[1, 1] = np.nan
df_corte.iloc[1, 2] = np.nan

df_caract = df_corte.iloc[:3]
df_corte = df_corte.iloc[2:]

# %%
df_caract = df_caract
df_caract.iloc[0, 1] = np.nan
df_caract.iloc[0, 2] = np.nan
df_caract.iloc[1, 1] = np.nan
df_caract.iloc[1, 2] = np.nan
df_caract.iloc[2, 0] = np.nan
df_caract.iloc[2, 1] = np.nan
df_caract.iloc[2, 2] = np.nan
df_caract.reset_index(drop=True, inplace=True)

df_caract = df_caract.T
# Renombrar las primeras columnas
listacol = df_caract.columns.tolist()
listacol[0] = 'Tipo de Caracteristica'
listacol[1] = 'Caracteristica'
listacol[2] = 'Atributo'
df_caract.columns = listacol

df_caract = df_caract.iloc[3:]   

df_caract
#excel
# Out:
#                                                                               Tipo de Caracteristica  \
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                       TOTAL
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      RANGO ETARIO
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                              Sexo
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                              Sexo
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...               Control con pareja, familiar u otro
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...          Control de diada con presencia del padre
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                  Espacios Amigables/ Adolescentes
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...       Niños, Niñas, Adolescentes y Jóvenes SENAME
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...  Niños, Niñas, Adolescentes y Jóvenes Mejor Niñez
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                               Pueblos Originarios
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                         Migrantes
#
#                                                                                       Caracteristica  \
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                       TOTAL
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                   Menos de 4 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      5  -  9 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      10 - 14 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      15 - 19 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      20 - 24 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      25 - 29 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      30 - 34 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      35 - 39 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      40 - 44 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      45 - 49 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      50 - 54 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      55 - 59 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      60 - 64 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      65 - 69 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      70 - 74 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                      75 - 79 años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                     80 y más años
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                           Hombres
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                           Mujeres
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...               Control con pareja, familiar u otro
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...          Control de diada con presencia del padre
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                  Espacios Amigables/ Adolescentes
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...       Niños, Niñas, Adolescentes y Jóvenes SENAME
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...  Niños, Niñas, Adolescentes y Jóvenes Mejor Niñez
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                               Pueblos Originarios
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...                                         Migrantes
#
#                                                    Atributo
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL01
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL02
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL03
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL04
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL05
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL06
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL07
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL08
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL09
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL10
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL11
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL12
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL13
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL14
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL15
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL16
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL17
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL18
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL19
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL20
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL21
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL22
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL23
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL24
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL25
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL26
# SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUC...    COL27

# %%
df_melted = pd.melt(df_corte, id_vars=['CODIGO PRESTACION', 'TIPO CONTROL', 'PROFESIONAL'], var_name='Columna', value_name='Atributo')

# Crear mapeos para tipos de características y características basados en los atributos
tipo_caracteristica_map = df_caract.set_index('Atributo')['Tipo de Caracteristica'].to_dict()
caracteristica_map = df_caract.set_index('Atributo')['Caracteristica'].to_dict()

# Mapear los tipos de características y características desde df_caract
df_melted['Tipo de Caracteristica'] = df_melted['Atributo'].map(tipo_caracteristica_map)
df_melted['Caracteristica'] = df_melted['Atributo'].map(caracteristica_map)
# Agregar la columna 'Seccion'
df_melted['Seccion'] = 'SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUCTIVA'

# Reordenar las columnas
df_melted = df_melted[['Seccion', 'CODIGO PRESTACION', 'TIPO CONTROL', 'PROFESIONAL', 'Tipo de Caracteristica', 'Caracteristica', 'Atributo']]
df_melted.dropna(subset=['CODIGO PRESTACION'], inplace=True)

df_melted
# Out:
#                                                Seccion CODIGO PRESTACION  \
# 1    SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010103
# 2    SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010201
# 3    SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010203
# 4    SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01501050
# 5    SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01501060
# ..                                                 ...               ...
# 589  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010603
# 590  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010901
# 591  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010903
# 592  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010401
# 593  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010403
#
#                  TIPO CONTROL PROFESIONAL Tipo de Caracteristica  \
# 1            Pre-Concepcional  Matrona/ón            TOTAL
# 2                    Prenatal    Médico/a            TOTAL
# 3                    Prenatal  Matrona/ón            TOTAL
# 4                  Post Parto    Médico/a            TOTAL
# 5                  Post Parto  Matrona/ón            TOTAL
# ..                        ...         ...                    ...
# 589              Ginecológico  Matrona/ón              Migrantes
# 590                Climaterio    Médico/a              Migrantes
# 591                Climaterio  Matrona/ón              Migrantes
# 592  Regulación de Fecundidad    Médico/a              Migrantes
# 593  Regulación de Fecundidad  Matrona/ón              Migrantes
#
#     Caracteristica Atributo
# 1      TOTAL          COL01
# 2      TOTAL          COL01
# 3      TOTAL          COL01
# 4      TOTAL          COL01
# 5      TOTAL          COL01
# ..             ...      ...
# 589      Migrantes    COL27
# 590      Migrantes    COL27
# 591      Migrantes    COL27
# 592      Migrantes    COL27
# 593      Migrantes    COL27
#
# [567 rows x 7 columns]

# %%
import pandas as pd


# Asegurar que las columnas dinámicas se identifiquen correctamente
columnas_dinamicas = [col for col in df_datos.columns if col.startswith('Col')]

# Transformar df_datos a formato largo, conservando las columnas relevantes
df_datos_long = df_datos.melt(
    id_vars=['Mes', 'IdServicio', 'Ano', 'IdEstablecimiento', 'CodigoPrestacion', 'IdRegion', 'IdComuna'],
    value_vars=columnas_dinamicas,
    var_name='Variable',
    value_name='Cantidad'
)
df_datos_long['IdEstablecimiento'].unique()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[5], line 8
#       5 columnas_dinamicas = [col for col in df_datos.columns if col.startswith('Col')]
#       7 # Transformar df_datos a formato largo, conservando las columnas relevantes
# ----> 8 df_datos_long = df_datos.melt(
#       9     id_vars=['Mes', 'IdServicio', 'Ano', 'IdEstablecimiento', 'CodigoPrestacion', 'IdRegion', 'IdComuna'],
#      10     value_vars=columnas_dinamicas,
#      11     var_name='Variable',
#      12     value_name='Cantidad'
#      13 )
#      14 df_datos_long['IdEstablecimiento'].unique()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:9942, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9932 @Appender(_shared_docs["melt"] % {"caller": "df.melt(", "other": "melt"})
#    9933 def melt(
#    9934     self,
#    (...)
#    9940     ignore_index: bool = True,
#    9941 ) -> DataFrame:
# -> 9942     return melt(
#    9943         self,
#    9944         id_vars=id_vars,
#    9945         value_vars=value_vars,
#    9946         var_name=var_name,
#    9947         value_name=value_name,
#    9948         col_level=col_level,
#    9949         ignore_index=ignore_index,
#    9950     ).__finalize__(self, method="melt")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\melt.py:133, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     130 for i, col in enumerate(var_name):
#     131     mdata[col] = frame.columns._get_level_values(i).repeat(num_rows)
# --> 133 result = frame._constructor(mdata, columns=mcolumns)
#     135 if not ignore_index:
#     136     result.index = tile_compat(frame.index, num_cols_adjusted)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:119, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:629, in _homogenize(data, index, dtype)
#     626         val = dict(val)
#     627     val = lib.fast_multiget(val, oindex._values, default=np.nan)
# --> 629 val = sanitize_array(val, index, dtype=dtype, copy=False)
#     630 com.require_length_match(val, index)
#     631 refs.append(None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\construction.py:606, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604 subarr = data
#     605 if data.dtype == object:
# --> 606     subarr = maybe_infer_to_datetimelike(data)
#     607     if (
#     608         object_index
#     609         and using_pyarrow_string_dtype()
#     610         and is_string_dtype(subarr)
#     611     ):
#     612         # Avoid inference when string option is set
#     613         subarr = data
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\cast.py:1189, in maybe_infer_to_datetimelike(value)
#    1184     return value
#    1186 # error: Incompatible return value type (got "Union[ExtensionArray,
#    1187 # ndarray[Any, Any]]", expected "Union[ndarray[Any, Any], DatetimeArray,
#    1188 # TimedeltaArray, PeriodArray, IntervalArray]")
# -> 1189 return lib.maybe_convert_objects(  # type: ignore[return-value]
#    1190     value,
#    1191     # Here we do not convert numeric dtypes, as if we wanted that,
#    1192     #  numpy would have done it for us.
#    1193     convert_numeric=False,
#    1194     convert_non_numeric=True,
#    1195     dtype_if_all_nat=np.dtype("M8[ns]"),
#    1196 )
#
# File lib.pyx:2540, in pandas._libs.lib.maybe_convert_objects()
#
# MemoryError: Unable to allocate 2.27 GiB for an array with shape (304979150,) and data type int64

# %%
# !jupyter notebook --NotebookApp.max_buffer_size=5000000000

# %%
result_list = []  # List to store intermediate results

for id_establecimiento in df_datos_long['IdEstablecimiento'].unique():
    df_melted['IdEstablecimiento'] = id_establecimiento
    df_melted['PK'] = df_melted['IdEstablecimiento'].astype(str) + df_melted['CODIGO PRESTACION'].astype(str).str.lstrip('0') + df_melted['Atributo'].str.upper()
    df_datos_long['PK'] = df_datos_long['IdEstablecimiento'].astype(str) + df_datos_long['CodigoPrestacion'].astype(str) + df_datos_long['Variable'].str.upper()
    df_partial = df_datos_long.merge(df_melted, how='inner', on='PK')  # Merge for the current id_establecimiento
    result_list.append(df_partial)  # Append the result to the list

df_final = pd.concat(result_list, ignore_index=True)  # Concatenate all partial results into a single DataFrame

# %%
df_final
# Out:
#       Mes  IdServicio   Ano  IdEstablecimiento_x CodigoPrestacion  IdRegion  \
# 0       7          16  2023               116551          1010103         7
# 1       7          16  2023               116551          1010103         7
# 2       7          16  2023               116551          1010103         7
# 3       7          16  2023               116551          1010103         7
# 4       7          16  2023               116551          1010103         7
# ...   ...         ...   ...                  ...              ...       ...
# 4558    8          16  2023               200233          1110107         7
# 4559    8          16  2023               200233          1110107         7
# 4560    8          16  2023               200233          1110107         7
# 4561    8          16  2023               200233          1110107         7
# 4562    8          16  2023               200233          1110107         7
#
#       IdComuna Variable  Cantidad                  PK  \
# 0         7404    Col01       1.0  1165511010103COL01
# 1         7404    Col02       NaN  1165511010103COL02
# 2         7404    Col03       NaN  1165511010103COL03
# 3         7404    Col04       NaN  1165511010103COL04
# 4         7404    Col05       NaN  1165511010103COL05
# ...        ...      ...       ...                 ...
# 4558      7105    Col23       NaN  2002331110107COL23
# 4559      7105    Col24       0.0  2002331110107COL24
# 4560      7105    Col25       0.0  2002331110107COL25
# 4561      7105    Col26       0.0  2002331110107COL26
# 4562      7105    Col27       0.0  2002331110107COL27
#
#                                                 Seccion CODIGO PRESTACION  \
# 0     SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010103
# 1     SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010103
# 2     SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010103
# 3     SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010103
# 4     SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01010103
# ...                                                 ...               ...
# 4558  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01110107
# 4559  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01110107
# 4560  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01110107
# 4561  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01110107
# 4562  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...          01110107
#
#                                            TIPO CONTROL PROFESIONAL  \
# 0                                      Pre-Concepcional  Matrona/ón
# 1                                      Pre-Concepcional  Matrona/ón
# 2                                      Pre-Concepcional  Matrona/ón
# 3                                      Pre-Concepcional  Matrona/ón
# 4                                      Pre-Concepcional  Matrona/ón
# ...                                                 ...         ...
# 4558  Puérpera con recién nacido hasta 10 días de vida   Matrona/ón
# 4559  Puérpera con recién nacido hasta 10 días de vida   Matrona/ón
# 4560  Puérpera con recién nacido hasta 10 días de vida   Matrona/ón
# 4561  Puérpera con recién nacido hasta 10 días de vida   Matrona/ón
# 4562  Puérpera con recién nacido hasta 10 días de vida   Matrona/ón
#
#                                 Tipo de Caracteristica  \
# 0                                          TOTAL
# 1                                         RANGO ETARIO
# 2                                         RANGO ETARIO
# 3                                         RANGO ETARIO
# 4                                         RANGO ETARIO
# ...                                                ...
# 4558                  Espacios Amigables/ Adolescentes
# 4559       Niños, Niñas, Adolescentes y Jóvenes SENAME
# 4560  Niños, Niñas, Adolescentes y Jóvenes Mejor Niñez
# 4561                               Pueblos Originarios
# 4562                                         Migrantes
#
#                                         Caracteristica Atributo  \
# 0                                          TOTAL          COL01
# 1                                      Menos de 4 años    COL02
# 2                                         5  -  9 años    COL03
# 3                                         10 - 14 años    COL04
# 4                                         15 - 19 años    COL05
# ...                                                ...      ...
# 4558                  Espacios Amigables/ Adolescentes    COL23
# 4559       Niños, Niñas, Adolescentes y Jóvenes SENAME    COL24
# 4560  Niños, Niñas, Adolescentes y Jóvenes Mejor Niñez    COL25
# 4561                               Pueblos Originarios    COL26
# 4562                                         Migrantes    COL27
#
#       IdEstablecimiento_y
# 0                  116551
# 1                  116551
# 2                  116551
# 3                  116551
# 4                  116551
# ...                   ...
# 4558               200233
# 4559               200233
# 4560               200233
# 4561               200233
# 4562               200233
#
# [4563 rows x 18 columns]

# %%
from sqlalchemy import create_engine

# Configura la conexión a la base de datos PostgreSQL
db_username = 'postgres'
db_password = '1234'
db_host = 'localhost'  # Cambia a la dirección de tu servidor PostgreSQL
db_port = '5432'       # Puerto por defecto de PostgreSQL
db_name = 'REM'        # Nombre de la base de datos

# Crea una conexión usando SQLAlchemy
engine = create_engine(f'postgresql+psycopg2://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}')

# Nombre de la tabla en PostgreSQL
table_name = 'A01SA_REM'

# Importa los datos del DataFrame a PostgreSQL
df_final.to_sql(table_name, engine, if_exists='replace', index=False)

print(f"Los datos se han importado correctamente a la tabla '{table_name}' en PostgreSQL.")
# Out:
# Los datos se han importado correctamente a la tabla 'A01SA_REM' en PostgreSQL.

# %%
#como seria el sql de mi tabla en postgresql
'''
CREATE TABLE "A01SA_REM" (
    "Mes" INT,
    "IdServicio" INT,
    "Ano" INT,
    "IdEstablecimiento_x" VARCHAR(50),
    "CodigoPrestacion" VARCHAR(50),
    "IdRegion" INT,
    "IdComuna" INT,
    "Variable" VARCHAR(50),
    "Cantidad" INT,
    "PK" VARCHAR(50),
    "Seccion" VARCHAR(255),
    "CODIGO_PRESTACION" VARCHAR(50),
    "TIPO_CONTROL" VARCHAR(50),
    "PROFESIONAL" VARCHAR(50),
    "Tipo_de_Caracteristica" VARCHAR(255),
    "Caracteristica" VARCHAR(255),
    "Atributo" VARCHAR(255),
    "IdEstablecimiento_y" VARCHAR(50)
);

select * from "A01SA_REM";
'''
