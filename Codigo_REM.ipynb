# %%
import pandas as pd

# Leer el archivo CSV con pandas
df_datos = pd.read_csv("SerieA2023.csv", sep=';')

# Convertir las columnas 'Col01' a 'Col50' a tipo float
for i in range(1, 51):
    col_name = f'Col{i:02d}'
    if col_name in df_datos.columns:
        df_datos[col_name] = df_datos[col_name].astype(float)

# Filtrar el DataFrame para la región específica
df_datos = df_datos[df_datos['IdRegion'] == 7]

# Mostrar el resultado
print(df_datos)
# Out:
#          Mes  IdServicio   Ano  IdEstablecimiento CodigoPrestacion  IdRegion  \
# 1264       8          16  2023             116111         04025010         7
# 1265       7          16  2023             116829         08230802         7
# 1266       7          16  2023             116829         08230803         7
# 1267       7          16  2023             116829         08230812         7
# 1268       7          16  2023             116829         08224000         7
# ...      ...         ...   ...                ...              ...       ...
# 6096138    9          16  2023             116306         27280400         7
# 6096139    9          16  2023             116306         27500250         7
# 6096140    9          16  2023             116306         27300918         7
# 6096141    9          16  2023             116306         27300902         7
# 6096142    9          16  2023             116306         27300903         7
#
# ...

# %%
import pandas as pd
import numpy as np
# Leer el archivo Excel
df_diccionario = pd.read_excel("A01.xlsx", skiprows=5)

# Rellenar valores faltantes hacia adelante
df_diccionario = df_diccionario.ffill(axis=0)
df_diccionario = df_diccionario.ffill(axis=1)

# Eliminar filas con menos de 3 valores no nulos
df_diccionario.dropna(axis=0, thresh=3, inplace=True)

# Limitar el DataFrame a las primeras 25 filas
df_corte = df_diccionario.iloc[:25]

# Establecer la primera fila como los nombres de las columnas y eliminar esa fila del DataFrame
df_corte.columns = df_corte.iloc[0]
df_corte = df_corte[1:]

# Renombrar las primeras columnas
listacol = df_corte.columns.tolist()
listacol[0] = 'CODIGO PRESTACION'
listacol[1] = 'TIPO CONTROL'
listacol[2] = 'PROFESIONAL'
df_corte.columns = listacol

df_corte = df_corte.iloc[:, :30]
df_corte.iloc[0, 1] = np.nan
df_corte.iloc[0, 2] = np.nan
df_corte.iloc[1, 1] = np.nan
df_corte.iloc[1, 2] = np.nan

df_caract = df_corte.iloc[:3]
df_corte = df_corte.iloc[2:]

# %%
df_caract = df_caract
df_caract.iloc[0, 1] = np.nan
df_caract.iloc[0, 2] = np.nan
df_caract.iloc[1, 1] = np.nan
df_caract.iloc[1, 2] = np.nan
df_caract.iloc[2, 0] = np.nan
df_caract.iloc[2, 1] = np.nan
df_caract.iloc[2, 2] = np.nan
df_caract.reset_index(drop=True, inplace=True)

df_caract = df_caract.T
# Renombrar las primeras columnas
listacol = df_caract.columns.tolist()
listacol[0] = 'Tipo de Caracteristica'
listacol[1] = 'Caracteristica'
listacol[2] = 'Atributo'
df_caract.columns = listacol

df_caract = df_caract.iloc[3:]

# %%
df_melted = pd.melt(df_corte, id_vars=['CODIGO PRESTACION', 'TIPO CONTROL', 'PROFESIONAL'], var_name='Columna', value_name='Atributo')

# Crear mapeos para tipos de características y características basados en los atributos
tipo_caracteristica_map = df_caract.set_index('Atributo')['Tipo de Caracteristica'].to_dict()
caracteristica_map = df_caract.set_index('Atributo')['Caracteristica'].to_dict()

# Mapear los tipos de características y características desde df_caract
df_melted['Tipo de Caracteristica'] = df_melted['Atributo'].map(tipo_caracteristica_map)
df_melted['Caracteristica'] = df_melted['Atributo'].map(caracteristica_map)
# Agregar la columna 'Seccion'
df_melted['Seccion'] = 'SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODUCTIVA'
df_melted['REM'] = 'REM 01'
df_melted['CODIGO PRESTACION'].astype(str).str.lstrip('0') 
# Reordenar las columnas
df_melted = df_melted[['REM', 'Seccion', 'CODIGO PRESTACION', 'TIPO CONTROL', 'PROFESIONAL', 'Tipo de Caracteristica', 'Caracteristica', 'Atributo']]
df_melted.dropna(subset=['CODIGO PRESTACION'], inplace=True)
df_melted
# Out:
#         REM                                            Seccion  \
# 1    REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 2    REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 3    REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 4    REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 5    REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# ..      ...                                                ...
# 589  REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 590  REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 591  REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 592  REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 593  REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
#
#     CODIGO PRESTACION              TIPO CONTROL PROFESIONAL  \
# 1            01010103          Pre-Concepcional  Matrona/ón
# 2            01010201                  Prenatal    Médico/a
# ...

# %%
import pandas as pd


# Asegurar que las columnas dinámicas se identifiquen correctamente
columnas_dinamicas = [col for col in df_datos.columns if col.startswith('Col')]

# Transformar df_datos a formato largo, conservando las columnas relevantes
df_datos_long = df_datos.melt(
    id_vars=['Mes', 'IdServicio', 'Ano', 'IdEstablecimiento', 'CodigoPrestacion', 'IdRegion', 'IdComuna'],
    value_vars=columnas_dinamicas,
    var_name='Variable',
    value_name='Cantidad'
    
)
df_datos_long['IdEstablecimiento'].unique()

existe_establecimiento = 116101 in df_datos_long['IdEstablecimiento']
print(existe_establecimiento)
# Out:
# True

# %%
result_list = []  # List to store intermediate results

# Filtrar el DataFrame para el establecimiento 116101
df_datos_long_filtered = df_datos_long[df_datos_long['IdEstablecimiento'] == 116101].copy()

# Iterar sobre cada 'IdEstablecimiento' (en este caso, solo 116101)
for id_establecimiento in df_datos_long_filtered['IdEstablecimiento'].unique():
    df_melted['IdEstablecimiento'] = id_establecimiento
    df_melted['PK'] = df_melted['IdEstablecimiento'].astype(str) + df_melted['CODIGO PRESTACION'].astype(str) + df_melted['Atributo'].str.upper()
    df_datos_long_filtered.loc[:, 'PK'] = df_datos_long_filtered['IdEstablecimiento'].astype(str) + df_datos_long_filtered['CodigoPrestacion'].astype(str) + df_datos_long_filtered['Variable'].str.upper()
    df_partial = df_datos_long_filtered.merge(df_melted, how='inner', on='PK')  # Merge for the current id_establecimiento
    result_list.append(df_partial)  # Append the result to the list
    
    

df_final = pd.concat(result_list, ignore_index=True)  # Concatenate all partial results into a single DataFrame

# Mostrar el resultado final
df_final.drop(columns=['IdEstablecimiento_y', 'Atributo' , 'CODIGO PRESTACION'], inplace=True)
df_final.rename(columns={'IdEstablecimiento_x': 'IdEstablecimiento' , 'TIPO CONTROL' : 'Tipo Control' ,'PROFESIONAL' : 'Profesional'}, inplace=True)
df_final = df_final[['REM', 'Seccion', 'IdEstablecimiento', 'PK', 'IdServicio', 'Ano', 'Mes', 'IdRegion', 'IdComuna', 'CodigoPrestacion', 'Tipo Control', 'Profesional', 'Tipo de Caracteristica', 'Caracteristica', 'Variable', 'Cantidad']]
df_final
# Out:
#          REM                                            Seccion  \
# 0     REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 1     REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 2     REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 3     REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 4     REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# ...      ...                                                ...
# 1912  REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 1913  REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 1914  REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 1915  REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
# 1916  REM 01  SECCIÓN A: CONTROLES DE SALUD SEXUAL Y REPRODU...
#
#       IdEstablecimiento                   PK  IdServicio   Ano  Mes  IdRegion  \
# 0                116101  11610101010103COL01          16  2023    8         7
# ...

# %%
#no ejecutar es para todos los establecimientos
result_list = []  # List to store intermediate results

for id_establecimiento in df_datos_long['IdEstablecimiento'].unique() == 116101:
    df_melted['IdEstablecimiento'] = id_establecimiento
    df_melted['PK'] = df_melted['IdEstablecimiento'].astype(str) + df_melted['CODIGO PRESTACION'].astype(str).str.lstrip('0') + df_melted['Atributo'].str.upper()
    df_datos_long['PK'] = df_datos_long['IdEstablecimiento'].astype(str) + df_datos_long['CodigoPrestacion'].astype(str) + df_datos_long['Variable'].str.upper()
    df_partial = df_datos_long.merge(df_melted, how='inner', on='PK')  # Merge for the current id_establecimiento
    result_list.append(df_partial)  # Append the result to the list

df_final = pd.concat(result_list, ignore_index=True)  # Concatenate all partial results into a single DataFrame

# %%
from sqlalchemy import create_engine

# Configura la conexión a la base de datos PostgreSQL
db_username = 'postgres'
db_password = '1234'
db_host = 'localhost'  # Cambia a la dirección de tu servidor PostgreSQL
db_port = '5432'       # Puerto por defecto de PostgreSQL
db_name = 'REM'        # Nombre de la base de datos

# Crea una conexión usando SQLAlchemy
engine = create_engine(f'postgresql+psycopg2://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}')

# Nombre de la tabla en PostgreSQL
table_name = 'A01'

# Importa los datos del DataFrame a PostgreSQL
df_final.to_sql(table_name, engine, if_exists='replace', index=False)

print(f"Los datos se han importado correctamente a la tabla '{table_name}' en PostgreSQL.")
# Out:
# Los datos se han importado correctamente a la tabla 'A01' en PostgreSQL.

# %%
'''
CREATE TABLE "A01" (
    "REM" VARCHAR(255),
    "Seccion" VARCHAR(255),
    "IdEstablecimiento" INT,
    "PK" VARCHAR(255),
    "IdServicio" INT,
    "Ano" INT,
    "Mes" INT,
    "IdRegion" INT,
    "IdComuna" INT,
    "CodigoPrestacion" VARCHAR(50),
    "Tipo Control" VARCHAR(50),
    "Profesional" VARCHAR(50),
    "Tipo de Caracteristica" VARCHAR(255),
    "Caracteristica" VARCHAR(255),
    "Variable" VARCHAR(50),
    "Cantidad" INT
);
'''
